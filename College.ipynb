# %%
#imports
from ISLP import load_data
import pandas as pd
import matplotlib.pyplot as plt

# %%
#load data
college = load_data('College')
college
# Out:
#     Private   Apps  Accept  Enroll  Top10perc  Top25perc  F.Undergrad  \
# 0       Yes   1660    1232     721         23         52         2885
# 1       Yes   2186    1924     512         16         29         2683
# 2       Yes   1428    1097     336         22         50         1036
# 3       Yes    417     349     137         60         89          510
# 4       Yes    193     146      55         16         44          249
# ..      ...    ...     ...     ...        ...        ...          ...
# 772      No   2197    1515     543          4         26         3089
# 773     Yes   1959    1805     695         24         47         2849
# 774     Yes   2097    1915     695         34         61         2793
# 775     Yes  10705    2453    1317         95         99         5217
# 776     Yes   2989    1855     691         28         63         2988
#
#      P.Undergrad  Outstate  Room.Board  Books  Personal  PhD  Terminal  \
# ...

# %%
#distribution descriptions
college.describe().iloc[:,:4]
# Out:
#                Apps        Accept       Enroll   Top10perc
# count    777.000000    777.000000   777.000000  777.000000
# mean    3001.638353   2018.804376   779.972973   27.558559
# std     3870.201484   2451.113971   929.176190   17.640364
# min       81.000000     72.000000    35.000000    1.000000
# 25%      776.000000    604.000000   242.000000   15.000000
# 50%     1558.000000   1110.000000   434.000000   23.000000
# 75%     3624.000000   2424.000000   902.000000   35.000000
# max    48094.000000  26330.000000  6392.000000   96.000000

# %%
#Scatterplot matrix for Top10perc, Apps, and Enroll

# Selecting the desired columns
columns_to_plot = ['Top10perc', 'Apps', 'Enroll']
subset_df = college[columns_to_plot]

# Creating a scatterplot matrix
scatter_matrix = pd.plotting.scatter_matrix(subset_df, alpha=0.8, figsize=(10, 10), diagonal='hist')

# Adding axis labels and adjusting layout
plt.suptitle('Scatterplot Matrix of Top10perc, Apps, and Enroll', y=0.95, fontsize=16)
plt.tight_layout(rect=(0, 0, 1, 0.95))

# Show the plot
plt.show()

# %%
# Boxplot of Outstate versus Private
college.boxplot(column='Outstate', by='Private', figsize=(8, 6))

# Adding labels and title
plt.title('Out-of-State Tuition for Private vs. Non-Private Colleges')
plt.xlabel('Private')
plt.ylabel('Out-of-State Tuition (dollars)')

# Show the plot
plt.show()

# %%
#elite status

#add elite column
college['Elite'] = pd.cut(college['Top10perc'],[0,50,100], labels=['No', 'Yes'])

#count elite counts
value_counts = college['Elite'].value_counts()
print(value_counts)
# Out:
#     Private   Apps  Accept  Enroll  Top10perc  Top25perc  F.Undergrad  \
# 0       Yes   1660    1232     721         23         52         2885
# 1       Yes   2186    1924     512         16         29         2683
# 2       Yes   1428    1097     336         22         50         1036
# 3       Yes    417     349     137         60         89          510
# 4       Yes    193     146      55         16         44          249
# ..      ...    ...     ...     ...        ...        ...          ...
# 772      No   2197    1515     543          4         26         3089
# 773     Yes   1959    1805     695         24         47         2849
# 774     Yes   2097    1915     695         34         61         2793
# 775     Yes  10705    2453    1317         95         99         5217
# 776     Yes   2989    1855     691         28         63         2988
#
#      P.Undergrad  Outstate  Room.Board  Books  Personal  PhD  Terminal  \
# ...

# %%
# Boxplot of Outstate versus Elite
college.boxplot(column='Outstate', by='Elite', figsize=(8, 6))

# Adding labels and title
plt.title('Out-of-State Tuition for Elite vs. Non-Elite Colleges')
plt.xlabel('Elite')
plt.ylabel('Out-of-State Tuition (dollars)')

# Show the plot
plt.show()
